# %%
# !pip install -q numpy
# !pip install -q scipy
# !pip install -q matplotlib
# !pip install -q scikit-image
# !pip install -q scikit-learn
# !pip install -q tensorflow
# !pip install -q flask
# !pip install -q werkzeug
# !pip install -q jinja
# !pip install -q pickle
# !pip install -q pillow
# !pip install -q kivy

# %%
import matplotlib.pyplot as plt
import numpy
from skimage import io

im = skimage.io.imread("images/IMG_0595.jpg", as_gray=False)
im1 = numpy.uint8(im*255)

# %%
skimage.io.imshow(im)

# %%
im1
# Out:
# array([[167, 173, 165, ..., 162, 155, 152],
#        [167, 168, 165, ..., 166, 154, 155],
#        [169, 165, 167, ..., 154, 160, 152],
#        ...,
#        [214, 215, 211, ..., 190, 191, 187],
#        [215, 215, 214, ..., 186, 186, 184],
#        [218, 215, 211, ..., 184, 183, 185]], dtype=uint8)

# %%
b = im1.ravel()
b.shape
# Out:
# (7990272,)

# %%
_ = plt.hist(b, bins='auto')
plt.show()

# %%
_ = plt.hist(b, bins=20)
plt.show()

# %%
hist

# %%
im1.shape
# Out:
# (3264, 2448)

# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.RandomState(10)
a = np.hstack((rng.normal(size=1000),
               rng.normal(loc=5, scale=2, size=1000)))
print(a.shape)
print('(min,max)', (a.min(),a.max()))
a
# Out:
# (2000,)
# (min,max) (-3.2044013443296304, 10.586331523462285)
# array([ 1.3315865 ,  0.71527897, -1.54540029, ...,  5.74446677,
#         6.22449239,  8.42055014])

# %%
_ = plt.hist(a, bins='auto')
plt.show()
