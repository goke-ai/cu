# %%
import pandas as pd

df_raw = pd.read_csv('Results-15(2) (Membrane A).csv',delimiter=',',header='infer')

df_raw.head()
# Out:
#          Label    Area     Mean  Min  Max       X      Y   Feret  %Area  \
# 0  1  15-1.jpg  12.721  117.544   80  126   2.456  1.711   7.001    100
# 1  2  15-1.jpg  57.922  119.616  101  126  21.234  6.185  16.350    100
# 2  3  15-1.jpg   7.280  120.536  106  126  65.438  0.972   6.581    100
# 3  4  15-1.jpg  12.271  120.006  108  126  73.006  1.916   6.461    100
# 4  5  15-1.jpg  29.721  115.855   93  126  85.000  1.850  12.629    100
#
#    FeretX  FeretY  FeretAngle  MinFeret         r         d
# 0       4      31      30.579     3.865  2.012137  4.024274
# 1     131     105      58.707    11.016  4.293571  8.587143
# 2     453       6       2.386     1.748  1.522168  3.044336
# 3     513      28      32.005     3.185  1.976227  3.952455
# 4     581       9       3.731     3.561  3.075591  6.151183

# %%
record = df_raw.iloc[0,:]

record
# Out:
#                      1
# Label         15-1.jpg
# Area            12.721
# Mean           117.544
# Min                 80
# Max                126
# X                2.456
# Y                1.711
# Feret            7.001
# %Area              100
# FeretX               4
# FeretY              31
# FeretAngle      30.579
# MinFeret         3.865
# r             2.012137
# d             4.024274
# Name: 0, dtype: object

# %%
import math
math.pi * record['r']**2
# Out:
# 12.719350774952236

# %%
df_raw.shape
# Out:
# (370, 16)

# %%
df_raw.describe()
# Out:
#                         Area        Mean         Min    Max           X  \
# count  370.00000  370.000000  370.000000  370.000000  370.0  370.000000
# mean   185.50000   32.704662  121.027127  108.002703  126.0   89.550516
# std    106.95404   49.456986    4.424984   16.032065    0.0   55.200025
# min      1.00000    0.019000  107.355000   57.000000  126.0    0.902000
# 25%     93.25000    2.931750  118.469500   97.000000  126.0   42.595250
# 50%    185.50000   13.772000  122.186000  113.000000  126.0   88.054500
# 75%    277.75000   42.161000  124.685500  122.000000  126.0  135.267500
# max    370.00000  316.985000  126.000000  126.000000  126.0  191.319000
#
#                 Y       Feret  %Area       FeretX       FeretY  FeretAngle  \
# count  370.000000  370.000000  370.0   370.000000   370.000000  370.000000
# mean    88.833632    9.228643  100.0   630.048649   645.886486   93.533665
# std     53.998407    8.664228    0.0   402.775328   396.229606   55.136730
# min      0.835000    0.194000  100.0     2.000000     3.000000    1.116000
# 25%     43.098250    2.635000  100.0   283.250000   298.000000   38.067000
# 50%     89.560500    6.585000  100.0   627.500000   633.000000   98.859500
# 75%    131.090000   13.009750  100.0   963.500000   963.250000  144.091750
# max    189.064000   50.658000  100.0  1388.000000  1386.000000  178.755000
#
#          MinFeret           r           d
# count  370.000000  370.000000  370.000000
# mean     4.675830    2.552949    5.105899
# std      4.121119    1.975313    3.950627
# min      0.137000    0.077763    0.155526
# 25%      1.573000    0.965962    1.931924
# 50%      3.614500    2.093604    4.187208
# 75%      6.502750    3.663126    7.326252
# max     20.935000   10.044221   20.088442

# %%
df_raw.head()
# Out:
#          Label    Area     Mean  Min  Max       X      Y   Feret  %Area  \
# 0  1  15-1.jpg  12.721  117.544   80  126   2.456  1.711   7.001    100
# 1  2  15-1.jpg  57.922  119.616  101  126  21.234  6.185  16.350    100
# 2  3  15-1.jpg   7.280  120.536  106  126  65.438  0.972   6.581    100
# 3  4  15-1.jpg  12.271  120.006  108  126  73.006  1.916   6.461    100
# 4  5  15-1.jpg  29.721  115.855   93  126  85.000  1.850  12.629    100
#
#    FeretX  FeretY  FeretAngle  MinFeret         r         d
# 0       4      31      30.579     3.865  2.012137  4.024274
# 1     131     105      58.707    11.016  4.293571  8.587143
# 2     453       6       2.386     1.748  1.522168  3.044336
# 3     513      28      32.005     3.185  1.976227  3.952455
# 4     581       9       3.731     3.561  3.075591  6.151183

# %%
df_raw.isnull().sum()
# Out:
#               0
# Label         0
# Area          0
# Mean          0
# Min           0
# Max           0
# X             0
# Y             0
# Feret         0
# %Area         0
# FeretX        0
# FeretY        0
# FeretAngle    0
# MinFeret      0
# r             0
# d             0
# dtype: int64

# %%
rmax = df_raw['r'].max()
rmin = df_raw['r'].min()

N = 20

h = (rmax - rmin) / N
h
# Out:
# 0.4983229002

# %%
import numpy as np

# intervals = np.arange(rmin, rmax, h)
intervals = np.linspace(rmin, rmax, N)

intervals
# Out:
# array([ 0.07776313,  0.60231355,  1.12686397,  1.65141439,  2.17596481,
#         2.70051523,  3.22506565,  3.74961607,  4.2741665 ,  4.79871692,
#         5.32326734,  5.84781776,  6.37236818,  6.8969186 ,  7.42146902,
#         7.94601944,  8.47056987,  8.99512029,  9.51967071, 10.04422113])

# %%
r = 1.95

r0 = intervals[0]

intervals

def select_radius_group(r):
    for i in range(1,N):
        if r <= intervals[i]: 
            return i, intervals[i-1], intervals[i]
    
    return 0, 0, 0      

select_radius_group(0.077764)
# Out:
# (1, 0.077763126, 0.6023135472631579)

# %%
arData = df_raw['r'].apply(lambda x: select_radius_group(x))

arData
# Out:
# 0      (4, 1.6514143897894737, 2.1759648110526313)
# 1        (9, 4.274166496105263, 4.798716917368421)
# 2      (3, 1.1268639685263158, 1.6514143897894737)
# 3      (4, 1.6514143897894737, 2.1759648110526313)
# 4       (6, 2.700515232315789, 3.2250656535789473)
#                           ...
# 365     (5, 2.1759648110526313, 2.700515232315789)
# 366           (1, 0.077763126, 0.6023135472631579)
# 367     (6, 2.700515232315789, 3.2250656535789473)
# 368    (2, 0.6023135472631579, 1.1268639685263158)
# 369     (5, 2.1759648110526313, 2.700515232315789)
# Name: r, Length: 370, dtype: object

# %%
df_raw[['RadiusGroup','lowerR', 'upperR']] = pd.DataFrame(list(arData))

df_raw.head()
# Out:
#          Label    Area     Mean  Min  Max       X      Y   Feret  %Area  \
# 0  1  15-1.jpg  12.721  117.544   80  126   2.456  1.711   7.001    100
# 1  2  15-1.jpg  57.922  119.616  101  126  21.234  6.185  16.350    100
# 2  3  15-1.jpg   7.280  120.536  106  126  65.438  0.972   6.581    100
# 3  4  15-1.jpg  12.271  120.006  108  126  73.006  1.916   6.461    100
# 4  5  15-1.jpg  29.721  115.855   93  126  85.000  1.850  12.629    100
#
#    FeretX  FeretY  FeretAngle  MinFeret         r         d  RadiusGroup  \
# 0       4      31      30.579     3.865  2.012137  4.024274            4
# 1     131     105      58.707    11.016  4.293571  8.587143            9
# 2     453       6       2.386     1.748  1.522168  3.044336            3
# 3     513      28      32.005     3.185  1.976227  3.952455            4
# 4     581       9       3.731     3.561  3.075591  6.151183            6
#
#      lowerR    upperR
# 0  1.651414  2.175965
# 1  4.274166  4.798717
# 2  1.126864  1.651414
# 3  1.651414  2.175965
# 4  2.700515  3.225066

# %%
df_raw.isnull().sum()
# Out:
#                0
# Label          0
# Area           0
# Mean           0
# Min            0
# Max            0
# X              0
# Y              0
# Feret          0
# %Area          0
# FeretX         0
# FeretY         0
# FeretAngle     0
# MinFeret       0
# r              0
# d              0
# RadiusGroup    0
# lowerR         0
# upperR         0
# dtype: int64

# %%
df_raw[df_raw.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ , Label, Area, Mean, Min, Max, X, Y, Feret, %Area, FeretX, FeretY, FeretAngle, MinFeret, r, d, RadiusGroup, lowerR, upperR]
# Index: []

# %%
dfW = df_raw[['r','RadiusGroup','lowerR', 'upperR']]

dfW.head()
# Out:
#           r  RadiusGroup    lowerR    upperR
# 0  2.012137            4  1.651414  2.175965
# 1  4.293571            9  4.274166  4.798717
# 2  1.522168            3  1.126864  1.651414
# 3  1.976227            4  1.651414  2.175965
# 4  3.075591            6  2.700515  3.225066

# %%
dfW[dfW['RadiusGroup'] < 1]
# Out:
# Empty DataFrame
# Columns: [r, RadiusGroup, lowerR, upperR]
# Index: []

# %%
dfW.loc[dfW['RadiusGroup'] < 1] = 1
# Out:
# C:\sdk\Python310\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
mean_radius = dfW['r'].mean()
mean_radius
# Out:
# 2.552949340227027

# %%
dfW[dfW.r > mean_radius]
# Out:
#             r  RadiusGroup    lowerR    upperR
# 1    4.293571            9  4.274166  4.798717
# 4    3.075591            6  2.700515  3.225066
# 5    4.282438            9  4.274166  4.798717
# 6    4.567863            9  4.274166  4.798717
# 7    4.626295            9  4.274166  4.798717
# ..        ...          ...       ...       ...
# 358  2.602269            5  2.175965  2.700515
# 361  2.728892            6  2.700515  3.225066
# 362  3.653343            7  3.225066  3.749616
# 363  2.671370            5  2.175965  2.700515
# 367  3.194621            6  2.700515  3.225066
#
# [150 rows x 4 columns]

# %%
df_group = dfW.groupby(['RadiusGroup','lowerR','upperR']).count()
df_group
# Out:
#                                  r
# RadiusGroup lowerR   upperR
# 1           0.077763 0.602314   43
# 2           0.602314 1.126864   69
# 3           1.126864 1.651414   43
# 4           1.651414 2.175965   36
# 5           2.175965 2.700515   38
# 6           2.700515 3.225066   31
# 7           3.225066 3.749616   18
# 8           3.749616 4.274166   21
# 9           4.274166 4.798717   24
# 10          4.798717 5.323267   13
# 11          5.323267 5.847818    7
# 12          5.847818 6.372368    7
# 13          6.372368 6.896919    7
# 14          6.896919 7.421469    3
# 15          7.421469 7.946019    1
# 16          7.946019 8.470570    3
# 17          8.470570 8.995120    2
# 18          8.995120 9.519671    1
# 19          9.519671 10.044221   3

# %%
df_group = df_group.reset_index()
df_group
# Out:
#     RadiusGroup    lowerR     upperR   r
# 0             1  0.077763   0.602314  43
# 1             2  0.602314   1.126864  69
# 2             3  1.126864   1.651414  43
# 3             4  1.651414   2.175965  36
# 4             5  2.175965   2.700515  38
# 5             6  2.700515   3.225066  31
# 6             7  3.225066   3.749616  18
# 7             8  3.749616   4.274166  21
# 8             9  4.274166   4.798717  24
# 9            10  4.798717   5.323267  13
# 10           11  5.323267   5.847818   7
# 11           12  5.847818   6.372368   7
# 12           13  6.372368   6.896919   7
# 13           14  6.896919   7.421469   3
# 14           15  7.421469   7.946019   1
# 15           16  7.946019   8.470570   3
# 16           17  8.470570   8.995120   2
# 17           18  8.995120   9.519671   1
# 18           19  9.519671  10.044221   3

# %%
# Ensure plots are displayed inline in the notebook
# %matplotlib inline

from matplotlib import pyplot as plt

# Create a bar plot of name vs grade
plt.bar(x=df_group['RadiusGroup'], height=df_group['r'])

# Display the plot
plt.show()

# %%
# Get the variable to examine
var_data = df_raw['r']

# Create a Figure
fig = plt.figure(figsize=(15,10))


plt.subplot(2,2,1)
# Plot a histogram
plt.hist(var_data)

plt.subplot(2,2,2)
# Plot a histogram
plt.hist(var_data, bins=10)

plt.subplot(2,2,3)
# Plot a histogram
plt.hist(var_data, bins=20)

plt.subplot(224)
# Plot a histogram
plt.hist(var_data, bins=30)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
# C:\Users\gokel\AppData\Local\Temp/ipykernel_11064/3647342162.py:30: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Get the variable to examine
var_data = df_raw['r']

# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.hist(var_data)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
# C:\Users\gokel\AppData\Local\Temp/ipykernel_11064/3597667031.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Get the variable to examine
var = df_raw['r']

# Get statistics
min_val = var.min()
max_val = var.max()
mean_val = var.mean()
med_val = var.median()
mod_val = var.mode()[0]

print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                        mean_val,
                                                                                        med_val,
                                                                                        mod_val,
                                                                                        max_val))

# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.hist(var, bins=30)

# Add lines for the statistics
plt.axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)
plt.axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
plt.axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
plt.axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
plt.axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

# Add titles and labels
plt.title('Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Show the figure
fig.show()
# Out:
# Minimum:0.08
# Mean:2.55
# Median:2.09
# Mode:0.13
# Maximum:10.04
# C:\Users\gokel\AppData\Local\Temp/ipykernel_11064/2044039076.py:36: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Get the variable to examine
var = df_raw['r']

# Create a Figure
fig = plt.figure(figsize=(10,4))

# Plot a histogram
plt.boxplot(var)

# Add titles and labels
plt.title('Data Distribution')

# Show the figure
fig.show()
# Out:
# C:\Users\gokel\AppData\Local\Temp/ipykernel_11064/73314176.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Create a function that we can re-use
def show_distribution(var_data):
    from matplotlib import pyplot as plt

    # Get statistics
    min_val = var_data.min()
    max_val = var_data.max()
    mean_val = var_data.mean()
    med_val = var_data.median()
    mod_val = var_data.mode()[0]

    print('Minimum:{:.2f}\nMean:{:.2f}\nMedian:{:.2f}\nMode:{:.2f}\nMaximum:{:.2f}\n'.format(min_val,
                                                                                            mean_val,
                                                                                            med_val,
                                                                                            mod_val,
                                                                                            max_val))

    # Create a figure for 2 subplots (2 rows, 1 column)
    fig, ax = plt.subplots(2, 1, figsize = (10,4))

    # Plot the histogram   
    ax[0].hist(var_data, bins=30)
    ax[0].set_ylabel('Frequency')

    # Add lines for the mean, median, and mode
    ax[0].axvline(x=min_val, color = 'gray', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mean_val, color = 'cyan', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=med_val, color = 'red', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=mod_val, color = 'yellow', linestyle='dashed', linewidth = 2)
    ax[0].axvline(x=max_val, color = 'gray', linestyle='dashed', linewidth = 2)

    # Plot the boxplot   
    ax[1].boxplot(var_data, vert=False)
    ax[1].set_xlabel('Value')

    # Add a title to the Figure
    fig.suptitle('Data Distribution')

    # Show the figure
    fig.show()

# Get the variable to examine
col = df_raw['r']
# Call the function
show_distribution(col)
# Out:
# Minimum:0.08
# Mean:2.55
# Median:2.09
# Mode:0.13
# Maximum:10.04
# C:\Users\gokel\AppData\Local\Temp/ipykernel_11064/267569120.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def show_density(var_data):
    from matplotlib import pyplot as plt

    fig = plt.figure(figsize=(10,4))

    # Plot density
    var_data.plot.density()

    # Add titles and labels
    plt.title('Data Density')

    # Show the mean, median, and mode
    plt.axvline(x=var_data.mean(), color = 'cyan', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.median(), color = 'red', linestyle='dashed', linewidth = 2)
    plt.axvline(x=var_data.mode()[0], color = 'yellow', linestyle='dashed', linewidth = 2)

    # Show the figure
    plt.show()

# Get the density of Grade
col = df_raw['r']
show_density(col)

# %%
# Get the variable to examine
col = df_raw[df_raw['r'] < 7]['r']
# Call the function
show_distribution(col)
# Out:
# Minimum:0.08
# Mean:2.36
# Median:2.01
# Mode:0.13
# Maximum:7.00
# C:\Users\gokel\AppData\Local\Temp/ipykernel_11064/267569120.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
q99 = df_raw.r.quantile(.971)
# Get the variable to examine
col = df_raw[df_raw.r < q99]['r']
# Call the function
show_distribution(col)
# Out:
# Minimum:0.08
# Mean:2.36
# Median:2.01
# Mode:0.13
# Maximum:7.00
# C:\Users\gokel\AppData\Local\Temp/ipykernel_11064/267569120.py:40: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Get the density
show_density(col)

# %%
for col_name in ['r']:
    col = df_raw[col_name]
    rng = col.max() - col.min()
    var = col.var()
    std = col.std()
    print('\n{}:\n - Range: {:.2f}\n - Variance: {:.2f}\n - Std.Dev: {:.2f}'.format(col_name, rng, var, std))
# Out:
# r:
#  - Range: 9.97
#  - Variance: 3.90
#  - Std.Dev: 1.98

# %%
import scipy.stats as stats

# Get the Grade column
col = df_raw['r']

# get the density
density = stats.gaussian_kde(col)

# Plot the density
col.plot.density()

# Get the mean and standard deviation
s = col.std()
m = col.mean()

# Annotate 1 stdev
x1 = [m-s, m+s]
y1 = density(x1)
plt.plot(x1,y1, color='magenta')
plt.annotate('1 std (68.26%)', (x1[1],y1[1]))

# Annotate 2 stdevs
x2 = [m-(s*2), m+(s*2)]
y2 = density(x2)
plt.plot(x2,y2, color='green')
plt.annotate('2 std (95.45%)', (x2[1],y2[1]))

# Annotate 3 stdevs
x3 = [m-(s*3), m+(s*3)]
y3 = density(x3)
plt.plot(x3,y3, color='orange')
plt.annotate('3 std (99.73%)', (x3[1],y3[1]))

# Show the location of the mean
plt.axvline(col.mean(), color='cyan', linestyle='dashed', linewidth=1)

plt.axis('off')

plt.show()

# %%
y1,y2,y3
# Out:
# (array([0.21518343, 0.09605144]),
#  array([0.00160274, 0.03136202]),
#  array([1.25790432e-09, 1.05041246e-02]))

# %%
dfW.describe()
# Out:
#                 r  RadiusGroup      lowerR      upperR
# count  370.000000   370.000000  370.000000  370.000000
# mean     2.552949     5.232432    2.297887    2.822438
# std      1.975313     3.787016    1.986481    1.986481
# min      0.077763     1.000000    0.077763    0.602314
# 25%      0.965962     2.000000    0.602314    1.126864
# 50%      2.093604     4.000000    1.651414    2.175965
# 75%      3.663126     7.000000    3.225066    3.749616
# max     10.044221    19.000000    9.519671   10.044221

# %%
df_sample = df_raw[df_raw['r'] < 7]
df_sample
# Out:
#              Label    Area     Mean  Min  Max        X        Y   Feret  \
# 0      1  15-1.jpg  12.721  117.544   80  126    2.456    1.711   7.001
# 1      2  15-1.jpg  57.922  119.616  101  126   21.234    6.185  16.350
# 2      3  15-1.jpg   7.280  120.536  106  126   65.438    0.972   6.581
# 3      4  15-1.jpg  12.271  120.006  108  126   73.006    1.916   6.461
# 4      5  15-1.jpg  29.721  115.855   93  126   85.000    1.850  12.629
# ..   ...       ...     ...      ...  ...  ...      ...      ...     ...
# 365  366  15-1.jpg  16.530  118.438  100  126  123.203  185.210   5.813
# 366  367  15-1.jpg   0.150  126.000  126  126   28.834  182.730   0.565
# 367  368  15-1.jpg  32.066  117.450   97  126   77.741  185.180  10.849
# 368  369  15-1.jpg   1.820  124.897  123  126  118.446  184.534   1.733
# 369  370  15-1.jpg  16.699  108.088   86  126  113.650  189.064   5.953
#
#      %Area  FeretX  FeretY  FeretAngle  MinFeret         r         d  \
# 0      100       4      31      30.579     3.865  2.012137  4.024274
# 1      100     131     105      58.707    11.016  4.293571  8.587143
# 2      100     453       6       2.386     1.748  1.522168  3.044336
# 3      100     513      28      32.005     3.185  1.976227  3.952455
# 4      100     581       9       3.731     3.561  3.075591  6.151183
# ..     ...     ...     ...         ...       ...       ...       ...
# 365    100     893    1328     124.439     4.549  2.293683  4.587365
# 366    100     210    1332     104.036     0.411  0.218496  0.436991
# 367    100     543    1386      37.304     6.473  3.194621  6.389241
# 368    100     863    1341     108.435     1.453  0.761084  1.522168
# 369    100     810    1372     156.975     3.736  2.305378  4.610756
#
#      RadiusGroup    lowerR    upperR
# 0              4  1.651414  2.175965
# 1              9  4.274166  4.798717
# 2              3  1.126864  1.651414
# 3              4  1.651414  2.175965
# 4              6  2.700515  3.225066
# ..           ...       ...       ...
# 365            5  2.175965  2.700515
# 366            1  0.077763  0.602314
# 367            6  2.700515  3.225066
# 368            2  0.602314  1.126864
# 369            5  2.175965  2.700515
#
# [359 rows x 19 columns]
